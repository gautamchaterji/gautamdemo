# %% [markdown]
# Configuring and testing ipynb in VS Code and how it works.

# %% [markdown]
# # Section 1

# %%
print("Hello, Kolkata!")
# Out:
# Hello, Kolkata!

# %% [markdown]
# # PAndas example

# %%
import pandas as pd

data = {
    "ticker": ["AAPL", "MSFT", "GOOGL", "AMZN", "NVDA"],
    "company": ["Apple Inc.", "Microsoft Corp.", "Alphabet Inc.", "Amazon.com Inc.", "NVIDIA Corp."],
    "price_usd": [212.45, 468.12, 178.34, 193.27, 131.88],
}

df = pd.DataFrame(data)

# %%
df[df["price_usd"] > 200]
print(df)
# Out:
#   ticker          company  price_usd
# 0   AAPL       Apple Inc.     212.45
# 1   MSFT  Microsoft Corp.     468.12
# 2  GOOGL    Alphabet Inc.     178.34
# 3   AMZN  Amazon.com Inc.     193.27
# 4   NVDA     NVIDIA Corp.     131.88
